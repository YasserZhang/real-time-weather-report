# %%
import requests
from bs4 import BeautifulSoup
import os
import re

# %% [markdown]
# ## Weather APIs Content and Cost Analysis

# %% [markdown]
# Here we compare paid and free API plans of each Weather API services, and also introduce retrieved contents in each API call from these API services.

# %% [markdown]
# ### Weather Channel API

# %% [markdown]
# The figure below shows services offered by different plans. All of the three plan categories have both free and paid versions. You can use these services for free as long as you are in the developer's plan. When you think the call frequency in the free plan can not satisfy your needs, you can upgrade to other versions of service such as Drizzle, Shower, and Downpour, which you have to pay.

# %% [markdown]
# <img src="./imgs/weatherChannelAPIsPlan.jpg" width='70%'>

# %% [markdown]
# ### Contents in each API call

# %% [markdown]
# Below is a typical API call, and here is a brief anatomy.
# 1, http://api.wunderground.com/api/ : api source website
# 2, 698c9ad01025f811 : your api key
# 3, conditions : current weather conditions, you can replace it with hourly, forecast, the complete keyword list can be found at https://www.wunderground.com/weather/api/d/docs
# 4, 39.74,-75.54 : geo coordinates of the location of interest

# %% [markdown]
# The call below gives us the current weather condition in Wilmington, DE.

# %%
#API Weather Channel
page = requests.get('http://api.wunderground.com/api/698c9ad01025f811/conditions/q/39.74,-75.54.json')
content = BeautifulSoup(page.content,'html.parser')
print(content)
# Out:
# {
#   "response": {
#   "version":"0.1",
#   "termsofService":"http://www.wunderground.com/weather/api/d/terms.html",
#   "features": {
#   "conditions": 1
#   }
# 	}
#   ,	"current_observation": {
# 		"image": {
# 		"url":"http://icons.wxug.com/graphics/wu2/logo_130x80.png",
# 		"title":"Weather Underground",
# 		"link":"http://www.wunderground.com"
# 		},
# 		"display_location": {
# 		"full":"Landlith, DE",
# 		"city":"Landlith",
# 		"state":"DE",
# 		"state_name":"Delaware",
# 		"country":"US",
# 		"country_iso3166":"US",
# 		"zip":"19802",
# 		"magic":"5",
# 		"wmo":"99999",
# 		"latitude":"39.740000",
# 		"longitude":"-75.540000",
# 		"elevation":"7.9"
# 		},
# 		"observation_location": {
# 		"full":"Wilmington, Delaware",
# 		"city":"Wilmington",
# 		"state":"Delaware",
# 		"country":"US",
# 		"country_iso3166":"US",
# 		"latitude":"39.76",
# 		"longitude":"-75.57",
# 		"elevation":"207 ft"
# 		},
# 		"estimated": {
# 		},
# 		"station_id":"KDEWILMI48",
# 		"observation_time":"Last Updated on April 16, 2:25 PM EDT",
# 		"observation_time_rfc822":"Mon, 16 Apr 2018 14:25:20 -0400",
# 		"observation_epoch":"1523903120",
# 		"local_time_rfc822":"Mon, 16 Apr 2018 14:25:30 -0400",
# 		"local_epoch":"1523903130",
# 		"local_tz_short":"EDT",
# 		"local_tz_long":"America/New_York",
# 		"local_tz_offset":"-0400",
# 		"weather":"Overcast",
# 		"temperature_string":"58.3 F (14.6 C)",
# 		"temp_f":58.3,
# 		"temp_c":14.6,
# 		"relative_humidity":"75%",
# 		"wind_string":"From the WNW at 1.1 MPH Gusting to 2.5 MPH",
# 		"wind_dir":"WNW",
# 		"wind_degrees":283,
# 		"wind_mph":1.1,
# 		"wind_gust_mph":"2.5",
# 		"wind_kph":1.8,
# 		"wind_gust_kph":"4.0",
# 		"pressure_mb":"997",
# 		"pressure_in":"29.45",
# 		"pressure_trend":"+",
# 		"dewpoint_string":"50 F (10 C)",
# 		"dewpoint_f":50,
# 		"dewpoint_c":10,
# 		"heat_index_string":"NA",
# 		"heat_index_f":"NA",
# 		"heat_index_c":"NA",
# 		"windchill_string":"NA",
# 		"windchill_f":"NA",
# 		"windchill_c":"NA",
# 		"feelslike_string":"58.3 F (14.6 C)",
# 		"feelslike_f":"58.3",
# 		"feelslike_c":"14.6",
# 		"visibility_mi":"10.0",
# 		"visibility_km":"16.1",
# 		"solarradiation":"283",
# 		"UV":"3.0","precip_1hr_string":"0.00 in ( 0 mm)",
# 		"precip_1hr_in":"0.00",
# 		"precip_1hr_metric":" 0",
# 		"precip_today_string":"1.57 in (40 mm)",
# 		"precip_today_in":"1.57",
# 		"precip_today_metric":"40",
# 		"icon":"cloudy",
# 		"icon_url":"http://icons.wxug.com/i/c/k/cloudy.gif",
# 		"forecast_url":"http://www.wunderground.com/US/DE/Landlith.html",
# 		"history_url":"http://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KDEWILMI48",
# 		"ob_url":"http://www.wunderground.com/cgi-bin/findweather/getForecast?query=39.764614,-75.571060",
# 		"nowcast":""
# 	}
# }

# %% [markdown]
# 3-day forecast of Wilmington, DE

# %%
page = requests.get('http://api.wunderground.com/api/698c9ad01025f811/forecast/q/39.74,-75.54.json')
content = BeautifulSoup(page.content,'html.parser')
print(content)
# Out:
# {
#   "response": {
#   "version":"0.1",
#   "termsofService":"http://www.wunderground.com/weather/api/d/terms.html",
#   "features": {
#   "forecast": 1
#   }
# 	}
# 		,
# 	"forecast":{
# 		"txt_forecast": {
# 		"date":"1:05 PM EDT",
# 		"forecastday": [
# 		{
# 		"period":0,
# 		"icon":"chancerain",
# 		"icon_url":"http://icons.wxug.com/i/c/k/chancerain.gif",
# 		"title":"Monday",
# 		"fcttext":"Cloudy with a few showers. High 62F. Winds W at 15 to 25 mph. Chance of rain 30%.",
# 		"fcttext_metric":"Windy with a few showers possible. High 17C. Winds W at 25 to 40 km/h. Chance of rain 30%.",
# 		"pop":"30"
# 		}
# 		,
# 		{
# 		"period":1,
# 		"icon":"nt_partlycloudy",
# 		"icon_url":"http://icons.wxug.com/i/c/k/nt_partlycloudy.gif",
# 		"title":"Monday Night",
# 		"fcttext":"Partly cloudy skies. Low 36F. Winds W at 15 to 25 mph.",
# 		"fcttext_metric":"Some clouds. Low 3C. Winds W at 25 to 40 km/h.",
# 		"pop":"10"
# 		}
# 		,
# 		{
# 		"period":2,
# 		"icon":"mostlycloudy",
# 		"icon_url":"http://icons.wxug.com/i/c/k/mostlycloudy.gif",
# 		"title":"Tuesday",
# 		"fcttext":"A mix of clouds and sun early, then becoming cloudy later in the day. High 47F. Winds W at 15 to 25 mph.",
# 		"fcttext_metric":"Partly cloudy skies during the morning hours will become overcast in the afternoon. High 9C. Winds W at 25 to 40 km/h.",
# 		"pop":"10"
# 		}
# 		,
# 		{
# 		"period":3,
# 		"icon":"nt_partlycloudy",
# 		"icon_url":"http://icons.wxug.com/i/c/k/nt_partlycloudy.gif",
# 		"title":"Tuesday Night",
# 		"fcttext":"Some clouds early will give way to generally clear conditions overnight. Low 34F. Winds W at 10 to 20 mph.",
# 		"fcttext_metric":"Some clouds early will give way to generally clear conditions overnight. Low 2C. Winds W at 15 to 30 km/h.",
# 		"pop":"0"
# 		}
# 		,
# 		{
# 		"period":4,
# 		"icon":"clear",
# 		"icon_url":"http://icons.wxug.com/i/c/k/clear.gif",
# 		"title":"Wednesday",
# 		"fcttext":"Sunny skies. High 59F. Winds W at 10 to 20 mph.",
# 		"fcttext_metric":"A mainly sunny sky. High around 15C. Winds W at 15 to 30 km/h.",
# 		"pop":"0"
# 		}
# 		,
# 		{
# 		"period":5,
# 		"icon":"nt_chancerain",
# 		"icon_url":"http://icons.wxug.com/i/c/k/nt_chancerain.gif",
# 		"title":"Wednesday Night",
# 		"fcttext":"Partly cloudy in the evening. Increasing clouds with periods of showers after midnight. Low 47F. Winds ESE at 5 to 10 mph. Chance of rain 60%.",
# 		"fcttext_metric":"Partly cloudy skies early followed by increasing clouds with showers developing later at night. Low 9C. Winds ESE at 10 to 15 km/h. Chance of rain 60%.",
# 		"pop":"60"
# 		}
# 		,
# 		{
# 		"period":6,
# 		"icon":"partlycloudy",
# 		"icon_url":"http://icons.wxug.com/i/c/k/partlycloudy.gif",
# 		"title":"Thursday",
# 		"fcttext":"Windy with increasing clouds. High 59F. Winds WNW at 20 to 30 mph.",
# 		"fcttext_metric":"Windy and becoming cloudy in the afternoon. High near 15C. Winds WNW at 30 to 50 km/h.",
# 		"pop":"20"
# 		}
# 		,
# 		{
# 		"period":7,
# 		"icon":"nt_partlycloudy",
# 		"icon_url":"http://icons.wxug.com/i/c/k/nt_partlycloudy.gif",
# 		"title":"Thursday Night",
# 		"fcttext":"Partly cloudy. Windy early. Low 39F. Winds NW at 20 to 30 mph.",
# 		"fcttext_metric":"Partly cloudy. Windy early. Low 4C. Winds NW at 30 to 50 km/h.",
# 		"pop":"0"
# 		}
# 		]
# 		},
# 		"simpleforecast": {
# 		"forecastday": [
# 		{"date":{
# 	"epoch":"1523919600",
# 	"pretty":"7:00 PM EDT on April 16, 2018",
# 	"day":16,
# 	"month":4,
# 	"year":2018,
# 	"yday":105,
# 	"hour":19,
# 	"min":"00",
# 	"sec":0,
# 	"isdst":"1",
# 	"monthname":"April",
# 	"monthname_short":"Apr",
# 	"weekday_short":"Mon",
# 	"weekday":"Monday",
# 	"ampm":"PM",
# 	"tz_short":"EDT",
# 	"tz_long":"America/New_York"
# },
# 		"period":1,
# 		"high": {
# 		"fahrenheit":"62",
# 		"celsius":"17"
# 		},
# 		"low": {
# 		"fahrenheit":"36",
# 		"celsius":"2"
# 		},
# 		"conditions":"Chance of Rain",
# 		"icon":"chancerain",
# 		"icon_url":"http://icons.wxug.com/i/c/k/chancerain.gif",
# 		"skyicon":"",
# 		"pop":30,
# 		"qpf_allday": {
# 		"in": 0.01,
# 		"mm": 0
# 		},
# 		"qpf_day": {
# 		"in": 0.01,
# 		"mm": 0
# 		},
# 		"qpf_night": {
# 		"in": 0.00,
# 		"mm": 0
# 		},
# 		"snow_allday": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"snow_day": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"snow_night": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"maxwind": {
# 		"mph": 25,
# 		"kph": 40,
# 		"dir": "W",
# 		"degrees": 273
# 		},
# 		"avewind": {
# 		"mph": 19,
# 		"kph": 31,
# 		"dir": "W",
# 		"degrees": 273
# 		},
# 		"avehumidity": 72,
# 		"maxhumidity": 0,
# 		"minhumidity": 0
# 		}
# 		,
# 		{"date":{
# 	"epoch":"1524006000",
# 	"pretty":"7:00 PM EDT on April 17, 2018",
# 	"day":17,
# 	"month":4,
# 	"year":2018,
# 	"yday":106,
# 	"hour":19,
# 	"min":"00",
# 	"sec":0,
# 	"isdst":"1",
# 	"monthname":"April",
# 	"monthname_short":"Apr",
# 	"weekday_short":"Tue",
# 	"weekday":"Tuesday",
# 	"ampm":"PM",
# 	"tz_short":"EDT",
# 	"tz_long":"America/New_York"
# },
# 		"period":2,
# 		"high": {
# 		"fahrenheit":"47",
# 		"celsius":"8"
# 		},
# 		"low": {
# 		"fahrenheit":"34",
# 		"celsius":"1"
# 		},
# 		"conditions":"Mostly Cloudy",
# 		"icon":"mostlycloudy",
# 		"icon_url":"http://icons.wxug.com/i/c/k/mostlycloudy.gif",
# 		"skyicon":"",
# 		"pop":10,
# 		"qpf_allday": {
# 		"in": 0.00,
# 		"mm": 0
# 		},
# 		"qpf_day": {
# 		"in": 0.00,
# 		"mm": 0
# 		},
# 		"qpf_night": {
# 		"in": 0.00,
# 		"mm": 0
# 		},
# 		"snow_allday": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"snow_day": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"snow_night": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"maxwind": {
# 		"mph": 25,
# 		"kph": 40,
# 		"dir": "W",
# 		"degrees": 271
# 		},
# 		"avewind": {
# 		"mph": 18,
# 		"kph": 29,
# 		"dir": "W",
# 		"degrees": 271
# 		},
# 		"avehumidity": 48,
# 		"maxhumidity": 0,
# 		"minhumidity": 0
# 		}
# 		,
# 		{"date":{
# 	"epoch":"1524092400",
# 	"pretty":"7:00 PM EDT on April 18, 2018",
# 	"day":18,
# 	"month":4,
# 	"year":2018,
# 	"yday":107,
# 	"hour":19,
# 	"min":"00",
# 	"sec":0,
# 	"isdst":"1",
# 	"monthname":"April",
# 	"monthname_short":"Apr",
# 	"weekday_short":"Wed",
# 	"weekday":"Wednesday",
# 	"ampm":"PM",
# 	"tz_short":"EDT",
# 	"tz_long":"America/New_York"
# },
# 		"period":3,
# 		"high": {
# 		"fahrenheit":"59",
# 		"celsius":"15"
# 		},
# 		"low": {
# 		"fahrenheit":"47",
# 		"celsius":"8"
# 		},
# 		"conditions":"Clear",
# 		"icon":"clear",
# 		"icon_url":"http://icons.wxug.com/i/c/k/clear.gif",
# 		"skyicon":"",
# 		"pop":0,
# 		"qpf_allday": {
# 		"in": 0.03,
# 		"mm": 1
# 		},
# 		"qpf_day": {
# 		"in": 0.00,
# 		"mm": 0
# 		},
# 		"qpf_night": {
# 		"in": 0.03,
# 		"mm": 1
# 		},
# 		"snow_allday": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"snow_day": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"snow_night": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"maxwind": {
# 		"mph": 20,
# 		"kph": 32,
# 		"dir": "W",
# 		"degrees": 266
# 		},
# 		"avewind": {
# 		"mph": 14,
# 		"kph": 23,
# 		"dir": "W",
# 		"degrees": 266
# 		},
# 		"avehumidity": 46,
# 		"maxhumidity": 0,
# 		"minhumidity": 0
# 		}
# 		,
# 		{"date":{
# 	"epoch":"1524178800",
# 	"pretty":"7:00 PM EDT on April 19, 2018",
# 	"day":19,
# 	"month":4,
# 	"year":2018,
# 	"yday":108,
# 	"hour":19,
# 	"min":"00",
# 	"sec":0,
# 	"isdst":"1",
# 	"monthname":"April",
# 	"monthname_short":"Apr",
# 	"weekday_short":"Thu",
# 	"weekday":"Thursday",
# 	"ampm":"PM",
# 	"tz_short":"EDT",
# 	"tz_long":"America/New_York"
# },
# 		"period":4,
# 		"high": {
# 		"fahrenheit":"59",
# 		"celsius":"15"
# 		},
# 		"low": {
# 		"fahrenheit":"39",
# 		"celsius":"4"
# 		},
# 		"conditions":"Partly Cloudy",
# 		"icon":"partlycloudy",
# 		"icon_url":"http://icons.wxug.com/i/c/k/partlycloudy.gif",
# 		"skyicon":"",
# 		"pop":20,
# 		"qpf_allday": {
# 		"in": 0.00,
# 		"mm": 0
# 		},
# 		"qpf_day": {
# 		"in": 0.00,
# 		"mm": 0
# 		},
# 		"qpf_night": {
# 		"in": 0.00,
# 		"mm": 0
# 		},
# 		"snow_allday": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"snow_day": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"snow_night": {
# 		"in": 0.0,
# 		"cm": 0.0
# 		},
# 		"maxwind": {
# 		"mph": 30,
# 		"kph": 48,
# 		"dir": "WNW",
# 		"degrees": 285
# 		},
# 		"avewind": {
# 		"mph": 23,
# 		"kph": 37,
# 		"dir": "WNW",
# 		"degrees": 285
# 		},
# 		"avehumidity": 59,
# 		"maxhumidity": 0,
# 		"minhumidity": 0
# 		}
# 		]
# 		}
# 	}
# }

# %% [markdown]
# ### Weatherbug API

# %% [markdown]
# There is a malfunction in the website's login system making us unable to log in and generate api keys.
# We will try it later.

# %% [markdown]
# ### Delaware Transportation Department

# %% [markdown]
# The department has a web platform that demonstrates weather related information collected from sensors set up all around the state.
# It only has a web platform, but does not offer API service.
# We need to scrape the webpage by ourselves, and codes below shows how we can download the data from the webpage.

# %%
from selenium import webdriver
browser = webdriver.Chrome() #replace with .Firefox(), or with the browser of your choice
url = "https://tmc.deldot.gov/sapps/tmcWeatherSummary/index.html"
browser.get(url) #navigate to the page

# %%
innerHTML = browser.execute_script("return document.body.innerHTML") #returns the inner HTML as a string

# %%
from lxml import html

# %%
htmlElem = html.document_fromstring(innerHTML) #make HTML element object

# %%
content = BeautifulSoup(innerHTML,'html.parser')

# %% [markdown]
# For each district, the website lists real-time reading of
# surface tempareture
# sub-surface temperature
# Air Temperature
# RH
# Dew
# Precipitation
# Visibility
# Wind
# Gusts
# Wind Direction

# %%
"""
the result show the following items in order:


    district
    surface tempareture  
    sub-surface temperature   
    Air Temperature  
    RH  
    Dew  
    Precipitation  
    Visibility  
    Wind  
    Gusts  
    Wind Direction
    

"""
for line in content.findAll('div',{'class':'x-grid-cell-inner'}):
    print(line.get_text())
# Out:
# District - North
# 61°
# 58°
# 51°
# 72%
# 42°
# 0.0 iph
# 2.5 mi
# 12 mph
# 25 mph
#
#
# District - Canal
# 59°
# 60°
# 52°
# 80%
# 46°
# 0.0 iph
# 3.8 mi
# 9 mph
# 18 mph
#
#
# District - Central
# 64°
# 56°
# 49°
# 80%
# 43°
# 0.0 iph
# 2.3 mi
# 10 mph
# 17 mph
#
#
# District - South
# 65°
# 63°
# 54°
# 74%
# 46°
# 0.0 iph
# 1.2 mi
# 13 mph
# 23 mph
#
#
# State - Coastline
# 62°
# 59°
# 53°
# 78%
# 46°
# 0.0 iph
# 2 mi
# 10 mph
# 21 mph
#
#
# State - Center
# 62°
# 58°
# 50°
# 81%
# 44°
# 0.0 iph
# 3.5 mi
# 10 mph
# 21 mph
#
#
# State - Western Border
# 60°
# 59°
# 53°
# 71%
# 43°
# 0.0 iph
# 1.2 mi
# 11 mph
# 21 mph

# %% [markdown]
# ### National Weather Service

# %% [markdown]
# The service is free and has APIs.
# Here is a brief explanation of the api code:
# 1, https://api.weather.gov/points/ : api address
# 2, 39.74,-75.54 : geo coordinates of the location of interest
# 3, forecast : forecast information
# 4, hourly : hourly forecast information.

# %% [markdown]
# The call below returns hourly weather forecast for the next 156 hours since the time of api request.

# %%
page = requests.get('https://api.weather.gov/points/39.74,-75.54/forecast/hourly')
content = BeautifulSoup(page.content,'html.parser')
content
# Out:
# {
#     "@context": [
#         "https://raw.githubusercontent.com/geojson/geojson-ld/master/contexts/geojson-base.jsonld",
#         {
#             "wx": "https://api.weather.gov/ontology#",
#             "geo": "http://www.opengis.net/ont/geosparql#",
#             "unit": "http://codes.wmo.int/common/unit/",
#             "@vocab": "https://api.weather.gov/ontology#"
#         }
#     ],
#     "type": "Feature",
#     "geometry": {
#         "type": "GeometryCollection",
#         "geometries": [
#             {
#                 "type": "Point",
#                 "coordinates": [
#                     -75.546473631192,
#                     39.733527762308
#                 ]
#             },
#             {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -75.558612981554,
#                             39.746014802735
#                         ],
#                         [
#                             -75.562710118391,
#                             39.724191846515
#                         ],
#                         [
#                             -75.534337188503,
#                             39.721039119576
#                         ],
#                         [
#                             -75.530234236238,
#                             39.742861754087
#                         ],
#                         [
#                             -75.558612981554,
#                             39.746014802735
#                         ]
#                     ]
#                 ]
#             }
#         ]
#     },
#     "properties": {
#         "updated": "2018-04-16T16:38:15+00:00",
#         "units": "us",
#         "forecastGenerator": "HourlyForecastGenerator",
#         "generatedAt": "2018-04-16T19:35:55+00:00",
#         "updateTime": "2018-04-16T16:38:15+00:00",
#         "validTimes": "2018-04-16T10:00:00+00:00/P7DT15H",
#         "elevation": {
#             "value": 20.1168,
#             "unitCode": "unit:m"
#         },
#         "periods": [
#             {
#                 "number": 1,
#                 "name": "",
#                 "startTime": "2018-04-16T15:00:00-04:00",
#                 "endTime": "2018-04-16T16:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 63,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "7 to 12 mph",
#                 "windDirection": "SW",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers,40?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 2,
#                 "name": "",
#                 "startTime": "2018-04-16T16:00:00-04:00",
#                 "endTime": "2018-04-16T17:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 61,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "13 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers,40?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 3,
#                 "name": "",
#                 "startTime": "2018-04-16T17:00:00-04:00",
#                 "endTime": "2018-04-16T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 58,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "13 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers,30?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 4,
#                 "name": "",
#                 "startTime": "2018-04-16T18:00:00-04:00",
#                 "endTime": "2018-04-16T19:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 56,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "13 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers,30?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 5,
#                 "name": "",
#                 "startTime": "2018-04-16T19:00:00-04:00",
#                 "endTime": "2018-04-16T20:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 54,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "13 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers,20?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 6,
#                 "name": "",
#                 "startTime": "2018-04-16T20:00:00-04:00",
#                 "endTime": "2018-04-16T21:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 51,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers,20?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 7,
#                 "name": "",
#                 "startTime": "2018-04-16T21:00:00-04:00",
#                 "endTime": "2018-04-16T22:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 49,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 8,
#                 "name": "",
#                 "startTime": "2018-04-16T22:00:00-04:00",
#                 "endTime": "2018-04-16T23:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 48,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 9,
#                 "name": "",
#                 "startTime": "2018-04-16T23:00:00-04:00",
#                 "endTime": "2018-04-17T00:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 48,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 10,
#                 "name": "",
#                 "startTime": "2018-04-17T00:00:00-04:00",
#                 "endTime": "2018-04-17T01:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 47,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 11,
#                 "name": "",
#                 "startTime": "2018-04-17T01:00:00-04:00",
#                 "endTime": "2018-04-17T02:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 45,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 12,
#                 "name": "",
#                 "startTime": "2018-04-17T02:00:00-04:00",
#                 "endTime": "2018-04-17T03:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 44,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 13,
#                 "name": "",
#                 "startTime": "2018-04-17T03:00:00-04:00",
#                 "endTime": "2018-04-17T04:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 43,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 14,
#                 "name": "",
#                 "startTime": "2018-04-17T04:00:00-04:00",
#                 "endTime": "2018-04-17T05:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 42,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 15,
#                 "name": "",
#                 "startTime": "2018-04-17T05:00:00-04:00",
#                 "endTime": "2018-04-17T06:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 41,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 16,
#                 "name": "",
#                 "startTime": "2018-04-17T06:00:00-04:00",
#                 "endTime": "2018-04-17T07:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 40,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/bkn?size=small",
#                 "shortForecast": "Partly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 17,
#                 "name": "",
#                 "startTime": "2018-04-17T07:00:00-04:00",
#                 "endTime": "2018-04-17T08:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 40,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/bkn?size=small",
#                 "shortForecast": "Partly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 18,
#                 "name": "",
#                 "startTime": "2018-04-17T08:00:00-04:00",
#                 "endTime": "2018-04-17T09:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 40,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/bkn?size=small",
#                 "shortForecast": "Partly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 19,
#                 "name": "",
#                 "startTime": "2018-04-17T09:00:00-04:00",
#                 "endTime": "2018-04-17T10:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 41,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "13 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/bkn?size=small",
#                 "shortForecast": "Partly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 20,
#                 "name": "",
#                 "startTime": "2018-04-17T10:00:00-04:00",
#                 "endTime": "2018-04-17T11:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 44,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "14 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/bkn?size=small",
#                 "shortForecast": "Partly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 21,
#                 "name": "",
#                 "startTime": "2018-04-17T11:00:00-04:00",
#                 "endTime": "2018-04-17T12:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 46,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "14 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 22,
#                 "name": "",
#                 "startTime": "2018-04-17T12:00:00-04:00",
#                 "endTime": "2018-04-17T13:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 48,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "15 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 23,
#                 "name": "",
#                 "startTime": "2018-04-17T13:00:00-04:00",
#                 "endTime": "2018-04-17T14:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 49,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "15 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 24,
#                 "name": "",
#                 "startTime": "2018-04-17T14:00:00-04:00",
#                 "endTime": "2018-04-17T15:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 50,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "15 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 25,
#                 "name": "",
#                 "startTime": "2018-04-17T15:00:00-04:00",
#                 "endTime": "2018-04-17T16:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 51,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "15 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 26,
#                 "name": "",
#                 "startTime": "2018-04-17T16:00:00-04:00",
#                 "endTime": "2018-04-17T17:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 51,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "15 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 27,
#                 "name": "",
#                 "startTime": "2018-04-17T17:00:00-04:00",
#                 "endTime": "2018-04-17T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 51,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "15 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 28,
#                 "name": "",
#                 "startTime": "2018-04-17T18:00:00-04:00",
#                 "endTime": "2018-04-17T19:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 51,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "15 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 29,
#                 "name": "",
#                 "startTime": "2018-04-17T19:00:00-04:00",
#                 "endTime": "2018-04-17T20:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 50,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "15 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 30,
#                 "name": "",
#                 "startTime": "2018-04-17T20:00:00-04:00",
#                 "endTime": "2018-04-17T21:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 48,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "15 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 31,
#                 "name": "",
#                 "startTime": "2018-04-17T21:00:00-04:00",
#                 "endTime": "2018-04-17T22:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 46,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "14 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 32,
#                 "name": "",
#                 "startTime": "2018-04-17T22:00:00-04:00",
#                 "endTime": "2018-04-17T23:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 45,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "13 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 33,
#                 "name": "",
#                 "startTime": "2018-04-17T23:00:00-04:00",
#                 "endTime": "2018-04-18T00:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 44,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/sct?size=small",
#                 "shortForecast": "Partly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 34,
#                 "name": "",
#                 "startTime": "2018-04-18T00:00:00-04:00",
#                 "endTime": "2018-04-18T01:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 43,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/sct?size=small",
#                 "shortForecast": "Partly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 35,
#                 "name": "",
#                 "startTime": "2018-04-18T01:00:00-04:00",
#                 "endTime": "2018-04-18T02:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 42,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "9 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/sct?size=small",
#                 "shortForecast": "Partly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 36,
#                 "name": "",
#                 "startTime": "2018-04-18T02:00:00-04:00",
#                 "endTime": "2018-04-18T03:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 41,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "9 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/sct?size=small",
#                 "shortForecast": "Partly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 37,
#                 "name": "",
#                 "startTime": "2018-04-18T03:00:00-04:00",
#                 "endTime": "2018-04-18T04:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 40,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "8 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/sct?size=small",
#                 "shortForecast": "Partly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 38,
#                 "name": "",
#                 "startTime": "2018-04-18T04:00:00-04:00",
#                 "endTime": "2018-04-18T05:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 40,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "9 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/sct?size=small",
#                 "shortForecast": "Partly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 39,
#                 "name": "",
#                 "startTime": "2018-04-18T05:00:00-04:00",
#                 "endTime": "2018-04-18T06:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 39,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "9 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/few?size=small",
#                 "shortForecast": "Mostly Clear",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 40,
#                 "name": "",
#                 "startTime": "2018-04-18T06:00:00-04:00",
#                 "endTime": "2018-04-18T07:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 40,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/few?size=small",
#                 "shortForecast": "Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 41,
#                 "name": "",
#                 "startTime": "2018-04-18T07:00:00-04:00",
#                 "endTime": "2018-04-18T08:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 40,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/few?size=small",
#                 "shortForecast": "Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 42,
#                 "name": "",
#                 "startTime": "2018-04-18T08:00:00-04:00",
#                 "endTime": "2018-04-18T09:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 40,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/few?size=small",
#                 "shortForecast": "Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 43,
#                 "name": "",
#                 "startTime": "2018-04-18T09:00:00-04:00",
#                 "endTime": "2018-04-18T10:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 43,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/few?size=small",
#                 "shortForecast": "Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 44,
#                 "name": "",
#                 "startTime": "2018-04-18T10:00:00-04:00",
#                 "endTime": "2018-04-18T11:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 47,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/few?size=small",
#                 "shortForecast": "Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 45,
#                 "name": "",
#                 "startTime": "2018-04-18T11:00:00-04:00",
#                 "endTime": "2018-04-18T12:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 50,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/few?size=small",
#                 "shortForecast": "Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 46,
#                 "name": "",
#                 "startTime": "2018-04-18T12:00:00-04:00",
#                 "endTime": "2018-04-18T13:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 53,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/few?size=small",
#                 "shortForecast": "Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 47,
#                 "name": "",
#                 "startTime": "2018-04-18T13:00:00-04:00",
#                 "endTime": "2018-04-18T14:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 55,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/few?size=small",
#                 "shortForecast": "Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 48,
#                 "name": "",
#                 "startTime": "2018-04-18T14:00:00-04:00",
#                 "endTime": "2018-04-18T15:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 57,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/few?size=small",
#                 "shortForecast": "Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 49,
#                 "name": "",
#                 "startTime": "2018-04-18T15:00:00-04:00",
#                 "endTime": "2018-04-18T16:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 59,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "12 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=small",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 50,
#                 "name": "",
#                 "startTime": "2018-04-18T16:00:00-04:00",
#                 "endTime": "2018-04-18T17:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 59,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "7 to 10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=small",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 51,
#                 "name": "",
#                 "startTime": "2018-04-18T17:00:00-04:00",
#                 "endTime": "2018-04-18T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 60,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 to 9 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=small",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 52,
#                 "name": "",
#                 "startTime": "2018-04-18T18:00:00-04:00",
#                 "endTime": "2018-04-18T19:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 60,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 to 7 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/sct?size=small",
#                 "shortForecast": "Partly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 53,
#                 "name": "",
#                 "startTime": "2018-04-18T19:00:00-04:00",
#                 "endTime": "2018-04-18T20:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 59,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 54,
#                 "name": "",
#                 "startTime": "2018-04-18T20:00:00-04:00",
#                 "endTime": "2018-04-18T21:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 58,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "SW",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 55,
#                 "name": "",
#                 "startTime": "2018-04-18T21:00:00-04:00",
#                 "endTime": "2018-04-18T22:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 56,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "2 mph",
#                 "windDirection": "SW",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 56,
#                 "name": "",
#                 "startTime": "2018-04-18T22:00:00-04:00",
#                 "endTime": "2018-04-18T23:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 54,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "SW",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 57,
#                 "name": "",
#                 "startTime": "2018-04-18T23:00:00-04:00",
#                 "endTime": "2018-04-19T00:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 53,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "S",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 58,
#                 "name": "",
#                 "startTime": "2018-04-19T00:00:00-04:00",
#                 "endTime": "2018-04-19T01:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 52,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "S",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 59,
#                 "name": "",
#                 "startTime": "2018-04-19T01:00:00-04:00",
#                 "endTime": "2018-04-19T02:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 52,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 60,
#                 "name": "",
#                 "startTime": "2018-04-19T02:00:00-04:00",
#                 "endTime": "2018-04-19T03:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 51,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 61,
#                 "name": "",
#                 "startTime": "2018-04-19T03:00:00-04:00",
#                 "endTime": "2018-04-19T04:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 50,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 62,
#                 "name": "",
#                 "startTime": "2018-04-19T04:00:00-04:00",
#                 "endTime": "2018-04-19T05:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 50,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "S",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 63,
#                 "name": "",
#                 "startTime": "2018-04-19T05:00:00-04:00",
#                 "endTime": "2018-04-19T06:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 49,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "S",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 64,
#                 "name": "",
#                 "startTime": "2018-04-19T06:00:00-04:00",
#                 "endTime": "2018-04-19T07:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 49,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "SW",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 65,
#                 "name": "",
#                 "startTime": "2018-04-19T07:00:00-04:00",
#                 "endTime": "2018-04-19T08:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 49,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "2 mph",
#                 "windDirection": "SW",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 66,
#                 "name": "",
#                 "startTime": "2018-04-19T08:00:00-04:00",
#                 "endTime": "2018-04-19T09:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 49,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "SW",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 67,
#                 "name": "",
#                 "startTime": "2018-04-19T09:00:00-04:00",
#                 "endTime": "2018-04-19T10:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 50,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "SW",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 68,
#                 "name": "",
#                 "startTime": "2018-04-19T10:00:00-04:00",
#                 "endTime": "2018-04-19T11:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 53,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "6 mph",
#                 "windDirection": "SW",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 69,
#                 "name": "",
#                 "startTime": "2018-04-19T11:00:00-04:00",
#                 "endTime": "2018-04-19T12:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 55,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 to 8 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 70,
#                 "name": "",
#                 "startTime": "2018-04-19T12:00:00-04:00",
#                 "endTime": "2018-04-19T13:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 57,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "6 to 9 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 71,
#                 "name": "",
#                 "startTime": "2018-04-19T13:00:00-04:00",
#                 "endTime": "2018-04-19T14:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 59,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 72,
#                 "name": "",
#                 "startTime": "2018-04-19T14:00:00-04:00",
#                 "endTime": "2018-04-19T15:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 60,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 73,
#                 "name": "",
#                 "startTime": "2018-04-19T15:00:00-04:00",
#                 "endTime": "2018-04-19T16:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 61,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 74,
#                 "name": "",
#                 "startTime": "2018-04-19T16:00:00-04:00",
#                 "endTime": "2018-04-19T17:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 61,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 75,
#                 "name": "",
#                 "startTime": "2018-04-19T17:00:00-04:00",
#                 "endTime": "2018-04-19T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 61,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "10 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers?size=small",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 76,
#                 "name": "",
#                 "startTime": "2018-04-19T18:00:00-04:00",
#                 "endTime": "2018-04-19T19:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 60,
#                 "temperatureUnit": "F",
# ...
#                 "shortForecast": "Mostly Clear",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 131,
#                 "name": "",
#                 "startTime": "2018-04-22T01:00:00-04:00",
#                 "endTime": "2018-04-22T02:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 48,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "6 mph",
#                 "windDirection": "N",
#                 "icon": "https://api.weather.gov/icons/land/night/few?size=small",
#                 "shortForecast": "Mostly Clear",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 132,
#                 "name": "",
#                 "startTime": "2018-04-22T02:00:00-04:00",
#                 "endTime": "2018-04-22T03:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 47,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "N",
#                 "icon": "https://api.weather.gov/icons/land/night/few?size=small",
#                 "shortForecast": "Mostly Clear",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 133,
#                 "name": "",
#                 "startTime": "2018-04-22T03:00:00-04:00",
#                 "endTime": "2018-04-22T04:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 46,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "N",
#                 "icon": "https://api.weather.gov/icons/land/night/few?size=small",
#                 "shortForecast": "Mostly Clear",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 134,
#                 "name": "",
#                 "startTime": "2018-04-22T04:00:00-04:00",
#                 "endTime": "2018-04-22T05:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 45,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "N",
#                 "icon": "https://api.weather.gov/icons/land/night/sct?size=small",
#                 "shortForecast": "Partly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 135,
#                 "name": "",
#                 "startTime": "2018-04-22T05:00:00-04:00",
#                 "endTime": "2018-04-22T06:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 45,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "N",
#                 "icon": "https://api.weather.gov/icons/land/night/sct?size=small",
#                 "shortForecast": "Partly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 136,
#                 "name": "",
#                 "startTime": "2018-04-22T06:00:00-04:00",
#                 "endTime": "2018-04-22T07:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 44,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "NE",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=small",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 137,
#                 "name": "",
#                 "startTime": "2018-04-22T07:00:00-04:00",
#                 "endTime": "2018-04-22T08:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 44,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "NE",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=small",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 138,
#                 "name": "",
#                 "startTime": "2018-04-22T08:00:00-04:00",
#                 "endTime": "2018-04-22T09:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 45,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "NE",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=small",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 139,
#                 "name": "",
#                 "startTime": "2018-04-22T09:00:00-04:00",
#                 "endTime": "2018-04-22T10:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 47,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "NE",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=small",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 140,
#                 "name": "",
#                 "startTime": "2018-04-22T10:00:00-04:00",
#                 "endTime": "2018-04-22T11:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 50,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "NE",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=small",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 141,
#                 "name": "",
#                 "startTime": "2018-04-22T11:00:00-04:00",
#                 "endTime": "2018-04-22T12:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 53,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "2 mph",
#                 "windDirection": "E",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=small",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 142,
#                 "name": "",
#                 "startTime": "2018-04-22T12:00:00-04:00",
#                 "endTime": "2018-04-22T13:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 55,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "2 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=small",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 143,
#                 "name": "",
#                 "startTime": "2018-04-22T13:00:00-04:00",
#                 "endTime": "2018-04-22T14:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 57,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "2 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/day/bkn?size=small",
#                 "shortForecast": "Partly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 144,
#                 "name": "",
#                 "startTime": "2018-04-22T14:00:00-04:00",
#                 "endTime": "2018-04-22T15:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 59,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "2 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/day/bkn?size=small",
#                 "shortForecast": "Partly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 145,
#                 "name": "",
#                 "startTime": "2018-04-22T15:00:00-04:00",
#                 "endTime": "2018-04-22T16:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 60,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/day/bkn?size=small",
#                 "shortForecast": "Partly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 146,
#                 "name": "",
#                 "startTime": "2018-04-22T16:00:00-04:00",
#                 "endTime": "2018-04-22T17:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 61,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/day/bkn?size=small",
#                 "shortForecast": "Partly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 147,
#                 "name": "",
#                 "startTime": "2018-04-22T17:00:00-04:00",
#                 "endTime": "2018-04-22T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 61,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/day/bkn?size=small",
#                 "shortForecast": "Partly Sunny",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 148,
#                 "name": "",
#                 "startTime": "2018-04-22T18:00:00-04:00",
#                 "endTime": "2018-04-22T19:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 60,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "6 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/bkn?size=small",
#                 "shortForecast": "Mostly Cloudy",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 149,
#                 "name": "",
#                 "startTime": "2018-04-22T19:00:00-04:00",
#                 "endTime": "2018-04-22T20:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 59,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "6 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 150,
#                 "name": "",
#                 "startTime": "2018-04-22T20:00:00-04:00",
#                 "endTime": "2018-04-22T21:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 57,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "6 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 151,
#                 "name": "",
#                 "startTime": "2018-04-22T21:00:00-04:00",
#                 "endTime": "2018-04-22T22:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 55,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "6 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 152,
#                 "name": "",
#                 "startTime": "2018-04-22T22:00:00-04:00",
#                 "endTime": "2018-04-22T23:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 53,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "6 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 153,
#                 "name": "",
#                 "startTime": "2018-04-22T23:00:00-04:00",
#                 "endTime": "2018-04-23T00:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 52,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 154,
#                 "name": "",
#                 "startTime": "2018-04-23T00:00:00-04:00",
#                 "endTime": "2018-04-23T01:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 50,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 155,
#                 "name": "",
#                 "startTime": "2018-04-23T01:00:00-04:00",
#                 "endTime": "2018-04-23T02:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 49,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             },
#             {
#                 "number": 156,
#                 "name": "",
#                 "startTime": "2018-04-23T02:00:00-04:00",
#                 "endTime": "2018-04-23T03:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 49,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 mph",
#                 "windDirection": "SE",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=small",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": ""
#             }
#         ]
#     }
# }

# %% [markdown]
# If we just call /forecast, it returns 7 days of weather forcast.

# %%
page = requests.get('https://api.weather.gov/points/39.74,-75.54/forecast')
content = BeautifulSoup(page.content,'html.parser')
content
# Out:
# {
#     "@context": [
#         "https://raw.githubusercontent.com/geojson/geojson-ld/master/contexts/geojson-base.jsonld",
#         {
#             "wx": "https://api.weather.gov/ontology#",
#             "geo": "http://www.opengis.net/ont/geosparql#",
#             "unit": "http://codes.wmo.int/common/unit/",
#             "@vocab": "https://api.weather.gov/ontology#"
#         }
#     ],
#     "type": "Feature",
#     "geometry": {
#         "type": "GeometryCollection",
#         "geometries": [
#             {
#                 "type": "Point",
#                 "coordinates": [
#                     -75.546473631192,
#                     39.733527762308
#                 ]
#             },
#             {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -75.558612981554,
#                             39.746014802735
#                         ],
#                         [
#                             -75.562710118391,
#                             39.724191846515
#                         ],
#                         [
#                             -75.534337188503,
#                             39.721039119576
#                         ],
#                         [
#                             -75.530234236238,
#                             39.742861754087
#                         ],
#                         [
#                             -75.558612981554,
#                             39.746014802735
#                         ]
#                     ]
#                 ]
#             }
#         ]
#     },
#     "properties": {
#         "updated": "2018-04-16T19:38:21+00:00",
#         "units": "us",
#         "forecastGenerator": "BaselineForecastGenerator",
#         "generatedAt": "2018-04-16T19:49:03+00:00",
#         "updateTime": "2018-04-16T19:38:21+00:00",
#         "validTimes": "2018-04-16T13:00:00+00:00/P8D",
#         "elevation": {
#             "value": 20.1168,
#             "unitCode": "unit:m"
#         },
#         "periods": [
#             {
#                 "number": 1,
#                 "name": "This Afternoon",
#                 "startTime": "2018-04-16T15:00:00-04:00",
#                 "endTime": "2018-04-16T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 64,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": "falling",
#                 "windSpeed": "12 to 20 mph",
#                 "windDirection": "SW",
#                 "icon": "https://api.weather.gov/icons/land/day/tsra,50?size=medium",
#                 "shortForecast": "Chance Showers And Thunderstorms",
#                 "detailedForecast": "A chance of showers and thunderstorms. Mostly cloudy. High near 64, with temperatures falling to around 53 in the afternoon. Southwest wind 12 to 20 mph, with gusts as high as 31 mph. Chance of precipitation is 50%. New rainfall amounts less than a tenth of an inch possible."
#             },
#             {
#                 "number": 2,
#                 "name": "Tonight",
#                 "startTime": "2018-04-16T18:00:00-04:00",
#                 "endTime": "2018-04-17T06:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 37,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "9 to 20 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/tsra,40/bkn?size=medium",
#                 "shortForecast": "Chance Showers And Thunderstorms then Mostly Cloudy",
#                 "detailedForecast": "A chance of showers and thunderstorms before 8pm. Mostly cloudy, with a low around 37. West wind 9 to 20 mph, with gusts as high as 31 mph. Chance of precipitation is 40%. New rainfall amounts less than a tenth of an inch possible."
#             },
#             {
#                 "number": 3,
#                 "name": "Tuesday",
#                 "startTime": "2018-04-17T06:00:00-04:00",
#                 "endTime": "2018-04-17T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 53,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "9 to 18 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/bkn/rain_showers,30?size=medium",
#                 "shortForecast": "Mostly Cloudy then Chance Rain Showers",
#                 "detailedForecast": "A chance of rain showers after 1pm. Mostly cloudy, with a high near 53. West wind 9 to 18 mph, with gusts as high as 30 mph. Chance of precipitation is 30%."
#             },
#             {
#                 "number": 4,
#                 "name": "Tuesday Night",
#                 "startTime": "2018-04-17T18:00:00-04:00",
#                 "endTime": "2018-04-18T06:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 36,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "8 to 18 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers,20/bkn?size=medium",
#                 "shortForecast": "Slight Chance Rain Showers then Mostly Cloudy",
#                 "detailedForecast": "A slight chance of rain showers before 7pm. Mostly cloudy, with a low around 36. West wind 8 to 18 mph, with gusts as high as 30 mph. Chance of precipitation is 20%."
#             },
#             {
#                 "number": 5,
#                 "name": "Wednesday",
#                 "startTime": "2018-04-18T06:00:00-04:00",
#                 "endTime": "2018-04-18T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 60,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "8 to 13 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=medium",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": "Mostly sunny, with a high near 60. West wind 8 to 13 mph, with gusts as high as 23 mph."
#             },
#             {
#                 "number": 6,
#                 "name": "Wednesday Night",
#                 "startTime": "2018-04-18T18:00:00-04:00",
#                 "endTime": "2018-04-19T06:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 47,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "3 to 10 mph",
#                 "windDirection": "SW",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers,30?size=medium",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": "A chance of rain showers after 8pm. Mostly cloudy, with a low around 47. Chance of precipitation is 30%. New rainfall amounts less than a tenth of an inch possible."
#             },
#             {
#                 "number": 7,
#                 "name": "Thursday",
#                 "startTime": "2018-04-19T06:00:00-04:00",
#                 "endTime": "2018-04-19T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 61,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 to 18 mph",
#                 "windDirection": "W",
#                 "icon": "https://api.weather.gov/icons/land/day/rain_showers,30?size=medium",
#                 "shortForecast": "Chance Rain Showers",
#                 "detailedForecast": "A chance of rain showers. Partly sunny, with a high near 61. Chance of precipitation is 30%."
#             },
#             {
#                 "number": 8,
#                 "name": "Thursday Night",
#                 "startTime": "2018-04-19T18:00:00-04:00",
#                 "endTime": "2018-04-20T06:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 40,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "13 to 17 mph",
#                 "windDirection": "NW",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers,30/sct?size=medium",
#                 "shortForecast": "Chance Rain Showers then Partly Cloudy",
#                 "detailedForecast": "A chance of rain showers before 8pm. Partly cloudy, with a low around 40. Chance of precipitation is 30%."
#             },
#             {
#                 "number": 9,
#                 "name": "Friday",
#                 "startTime": "2018-04-20T06:00:00-04:00",
#                 "endTime": "2018-04-20T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 55,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "14 mph",
#                 "windDirection": "NW",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=medium",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": "Mostly sunny, with a high near 55."
#             },
#             {
#                 "number": 10,
#                 "name": "Friday Night",
#                 "startTime": "2018-04-20T18:00:00-04:00",
#                 "endTime": "2018-04-21T06:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 38,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "8 to 13 mph",
#                 "windDirection": "NW",
#                 "icon": "https://api.weather.gov/icons/land/night/sct?size=medium",
#                 "shortForecast": "Partly Cloudy",
#                 "detailedForecast": "Partly cloudy, with a low around 38."
#             },
#             {
#                 "number": 11,
#                 "name": "Saturday",
#                 "startTime": "2018-04-21T06:00:00-04:00",
#                 "endTime": "2018-04-21T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 58,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "9 mph",
#                 "windDirection": "NW",
#                 "icon": "https://api.weather.gov/icons/land/day/sct?size=medium",
#                 "shortForecast": "Mostly Sunny",
#                 "detailedForecast": "Mostly sunny, with a high near 58."
#             },
#             {
#                 "number": 12,
#                 "name": "Saturday Night",
#                 "startTime": "2018-04-21T18:00:00-04:00",
#                 "endTime": "2018-04-22T06:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 41,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 to 8 mph",
#                 "windDirection": "N",
#                 "icon": "https://api.weather.gov/icons/land/night/sct?size=medium",
#                 "shortForecast": "Partly Cloudy",
#                 "detailedForecast": "Partly cloudy, with a low around 41."
#             },
#             {
#                 "number": 13,
#                 "name": "Sunday",
#                 "startTime": "2018-04-22T06:00:00-04:00",
#                 "endTime": "2018-04-22T18:00:00-04:00",
#                 "isDaytime": true,
#                 "temperature": 61,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "NE",
#                 "icon": "https://api.weather.gov/icons/land/day/sct/rain_showers?size=medium",
#                 "shortForecast": "Mostly Sunny then Slight Chance Rain Showers",
#                 "detailedForecast": "A slight chance of rain showers after 2pm. Mostly sunny, with a high near 61."
#             },
#             {
#                 "number": 14,
#                 "name": "Sunday Night",
#                 "startTime": "2018-04-22T18:00:00-04:00",
#                 "endTime": "2018-04-23T06:00:00-04:00",
#                 "isDaytime": false,
#                 "temperature": 41,
#                 "temperatureUnit": "F",
#                 "temperatureTrend": null,
#                 "windSpeed": "5 mph",
#                 "windDirection": "E",
#                 "icon": "https://api.weather.gov/icons/land/night/rain_showers?size=medium",
#                 "shortForecast": "Slight Chance Rain Showers",
#                 "detailedForecast": "A slight chance of rain showers before 2am. Partly cloudy, with a low around 41."
#             }
#         ]
#     }
# }

# %% [markdown]
# ### IBM Weather Company Data API

# %% [markdown]
# The IBM API both has free and paid plans as shown in the figure below.

# %% [markdown]
# <img src="./imgs/IBM_API_plans.jpg" width='70%'>

# %% [markdown]
# A brief explanation of the api:
# 1, https://443c601f-53bd-460e-aeab-21f85f5df7bc:xs48O8pSRA@twcservice.mybluemix.net : this is your api key
# 2, /api/weather/v1/ : api address
# 3, geocode/ : tell the service you will give him geo code
# 4, 39.74/-75.54 : geo coordinates of the location of interest
# 5, forecast/hourly/ : hourly forecast  (more options can be found at this link, https://console.bluemix.net/docs/services/Weather/weather_rest_apis.html#rest_apis, you may need to log in)
# 6, 48hour.json : in the time span of 48 hours, and in json format.

# %% [markdown]
# The code below shows a sample API retrieval for 48 hourly weather forcast in Wilmington, DE.

# %%
page = requests.get('https://443c601f-53bd-460e-aeab-21f85f5df7bc:xs48O8pSRA@twcservice.mybluemix.net/api/weather/v1/geocode/39.74/-75.54/forecast/hourly/48hour.json')

# %%
page.json()
# Out:
# {'forecasts': [{'class': 'fod_short_range_hourly',
#    'clds': 100,
#    'day_ind': 'D',
#    'dewpt': 44,
#    'dow': 'Monday',
#    'expire_time_gmt': 1523909235,
#    'fcst_valid': 1523908800,
#    'fcst_valid_local': '2018-04-16T16:00:00-0400',
#    'feels_like': 45,
#    'golf_category': 'Very Poor',
#    'golf_index': 0,
#    'gust': 28,
#    'hi': 51,
#    'icon_code': 12,
#    'icon_extd': 1210,
#    'mslp': 29.5,
#    'num': 1,
#    'phrase_12char': 'Rain/Wind',
#    'phrase_22char': 'Rain/Wind',
#    'phrase_32char': 'Rain/Wind',
#    'pop': 90,
#    'precip_type': 'rain',
#    'qpf': 0.03,
#    'rh': 76,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Rain',
#    'subphrase_pt2': 'Windy',
#    'subphrase_pt3': '',
#    'temp': 51,
#    'uv_desc': 'Low',
#    'uv_index': 1,
#    'uv_index_raw': 1.48,
#    'uv_warning': 0,
#    'vis': 7.0,
#    'wc': 45,
#    'wdir': 275,
#    'wdir_cardinal': 'W',
#    'wspd': 20,
#    'wxman': 'wx2551'},
#   {'class': 'fod_short_range_hourly',
#    'clds': 80,
#    'day_ind': 'D',
#    'dewpt': 41,
#    'dow': 'Monday',
#    'expire_time_gmt': 1523909235,
#    'fcst_valid': 1523912400,
#    'fcst_valid_local': '2018-04-16T17:00:00-0400',
#    'feels_like': 45,
#    'golf_category': 'Very Poor',
#    'golf_index': 1,
#    'gust': 29,
#    'hi': 51,
#    'icon_code': 11,
#    'icon_extd': 1211,
#    'mslp': 29.53,
#    'num': 2,
#    'phrase_12char': 'Light Rain',
#    'phrase_22char': 'Light Rain/Wind',
#    'phrase_32char': 'Light Rain/Wind',
#    'pop': 61,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 70,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Light',
#    'subphrase_pt2': 'Rain',
#    'subphrase_pt3': 'Windy',
#    'temp': 51,
#    'uv_desc': 'Low',
#    'uv_index': 1,
#    'uv_index_raw': 1.1,
#    'uv_warning': 0,
#    'vis': 7.0,
#    'wc': 45,
#    'wdir': 277,
#    'wdir_cardinal': 'W',
#    'wspd': 20,
#    'wxman': 'wx2551'},
#   {'class': 'fod_short_range_hourly',
#    'clds': 94,
#    'day_ind': 'D',
#    'dewpt': 40,
#    'dow': 'Monday',
#    'expire_time_gmt': 1523909235,
#    'fcst_valid': 1523916000,
#    'fcst_valid_local': '2018-04-16T18:00:00-0400',
#    'feels_like': 44,
#    'golf_category': 'Good',
#    'golf_index': 6,
#    'gust': 24,
#    'hi': 50,
#    'icon_code': 26,
#    'icon_extd': 2600,
#    'mslp': 29.57,
#    'num': 3,
#    'phrase_12char': 'Cloudy',
#    'phrase_22char': 'Cloudy',
#    'phrase_32char': 'Cloudy',
#    'pop': 15,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 67,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Cloudy',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 50,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0.26,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 44,
#    'wdir': 275,
#    'wdir_cardinal': 'W',
#    'wspd': 18,
#    'wxman': 'wx1250'},
#   {'class': 'fod_short_range_hourly',
#    'clds': 76,
#    'day_ind': 'D',
#    'dewpt': 38,
#    'dow': 'Monday',
#    'expire_time_gmt': 1523909235,
#    'fcst_valid': 1523919600,
#    'fcst_valid_local': '2018-04-16T19:00:00-0400',
#    'feels_like': 43,
#    'golf_category': 'Good',
#    'golf_index': 6,
#    'gust': 24,
#    'hi': 49,
#    'icon_code': 28,
#    'icon_extd': 2800,
#    'mslp': 29.6,
#    'num': 4,
#    'phrase_12char': 'M Cloudy',
#    'phrase_22char': 'Mostly Cloudy',
#    'phrase_32char': 'Mostly Cloudy',
#    'pop': 15,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 65,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Mostly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 49,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0.06,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 43,
#    'wdir': 276,
#    'wdir_cardinal': 'W',
#    'wspd': 18,
#    'wxman': 'wx1250'},
#   {'class': 'fod_short_range_hourly',
#    'clds': 70,
#    'day_ind': 'N',
#    'dewpt': 36,
#    'dow': 'Monday',
#    'expire_time_gmt': 1523909235,
#    'fcst_valid': 1523923200,
#    'fcst_valid_local': '2018-04-16T20:00:00-0400',
#    'feels_like': 41,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 24,
#    'hi': 47,
#    'icon_code': 27,
#    'icon_extd': 2700,
#    'mslp': 29.62,
#    'num': 5,
#    'phrase_12char': 'M Cloudy',
#    'phrase_22char': 'Mostly Cloudy',
#    'phrase_32char': 'Mostly Cloudy',
#    'pop': 17,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 66,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Mostly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 47,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 41,
#    'wdir': 280,
#    'wdir_cardinal': 'W',
#    'wspd': 14,
#    'wxman': 'wx1250'},
#   {'class': 'fod_short_range_hourly',
#    'clds': 59,
#    'day_ind': 'N',
#    'dewpt': 35,
#    'dow': 'Monday',
#    'expire_time_gmt': 1523909235,
#    'fcst_valid': 1523926800,
#    'fcst_valid_local': '2018-04-16T21:00:00-0400',
#    'feels_like': 40,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 18,
#    'hi': 45,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.64,
#    'num': 6,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 15,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 67,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 45,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 40,
#    'wdir': 278,
#    'wdir_cardinal': 'W',
#    'wspd': 10,
#    'wxman': 'wx1650'},
#   {'class': 'fod_short_range_hourly',
#    'clds': 52,
#    'day_ind': 'N',
#    'dewpt': 34,
#    'dow': 'Monday',
#    'expire_time_gmt': 1523909235,
#    'fcst_valid': 1523930400,
#    'fcst_valid_local': '2018-04-16T22:00:00-0400',
#    'feels_like': 40,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 18,
#    'hi': 45,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.66,
#    'num': 7,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 15,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 66,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 45,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 40,
#    'wdir': 275,
#    'wdir_cardinal': 'W',
#    'wspd': 10,
#    'wxman': 'wx1610'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 39,
#    'day_ind': 'N',
#    'dewpt': 32,
#    'dow': 'Monday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523934000,
#    'fcst_valid_local': '2018-04-16T23:00:00-0400',
#    'feels_like': 37,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 23,
#    'hi': 43,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.66,
#    'num': 8,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 2,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 63,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 43,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 37,
#    'wdir': 276,
#    'wdir_cardinal': 'W',
#    'wspd': 13,
#    'wxman': 'wx1610'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 47,
#    'day_ind': 'N',
#    'dewpt': 31,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523937600,
#    'fcst_valid_local': '2018-04-17T00:00:00-0400',
#    'feels_like': 36,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 24,
#    'hi': 43,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.67,
#    'num': 9,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 1,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 62,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 43,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 36,
#    'wdir': 280,
#    'wdir_cardinal': 'W',
#    'wspd': 13,
#    'wxman': 'wx1610'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 46,
#    'day_ind': 'N',
#    'dewpt': 29,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523941200,
#    'fcst_valid_local': '2018-04-17T01:00:00-0400',
#    'feels_like': 35,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 23,
#    'hi': 42,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.68,
#    'num': 10,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 1,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 59,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 42,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 35,
#    'wdir': 281,
#    'wdir_cardinal': 'W',
#    'wspd': 14,
#    'wxman': 'wx1610'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 44,
#    'day_ind': 'N',
#    'dewpt': 27,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523944800,
#    'fcst_valid_local': '2018-04-17T02:00:00-0400',
#    'feels_like': 34,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 24,
#    'hi': 41,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.68,
#    'num': 11,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 1,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 57,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 41,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 34,
#    'wdir': 282,
#    'wdir_cardinal': 'W',
#    'wspd': 15,
#    'wxman': 'wx1610'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 59,
#    'day_ind': 'N',
#    'dewpt': 27,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523948400,
#    'fcst_valid_local': '2018-04-17T03:00:00-0400',
#    'feels_like': 33,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 24,
#    'hi': 40,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.69,
#    'num': 12,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 1,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 59,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 40,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 33,
#    'wdir': 280,
#    'wdir_cardinal': 'W',
#    'wspd': 14,
#    'wxman': 'wx1610'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 56,
#    'day_ind': 'N',
#    'dewpt': 27,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523952000,
#    'fcst_valid_local': '2018-04-17T04:00:00-0400',
#    'feels_like': 31,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 23,
#    'hi': 39,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.69,
#    'num': 13,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 1,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 62,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 39,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 31,
#    'wdir': 276,
#    'wdir_cardinal': 'W',
#    'wspd': 14,
#    'wxman': 'wx1610'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 43,
#    'day_ind': 'N',
#    'dewpt': 27,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523955600,
#    'fcst_valid_local': '2018-04-17T05:00:00-0400',
#    'feels_like': 30,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 22,
#    'hi': 38,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.69,
#    'num': 14,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 2,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 63,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 38,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 30,
#    'wdir': 271,
#    'wdir_cardinal': 'W',
#    'wspd': 13,
#    'wxman': 'wx1610'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 40,
#    'day_ind': 'N',
#    'dewpt': 26,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523959200,
#    'fcst_valid_local': '2018-04-17T06:00:00-0400',
#    'feels_like': 29,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 23,
#    'hi': 38,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.7,
#    'num': 15,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 2,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 63,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 38,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 29,
#    'wdir': 265,
#    'wdir_cardinal': 'W',
#    'wspd': 13,
#    'wxman': 'wx1610'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 37,
#    'day_ind': 'D',
#    'dewpt': 26,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523962800,
#    'fcst_valid_local': '2018-04-17T07:00:00-0400',
#    'feels_like': 29,
#    'golf_category': 'Poor',
#    'golf_index': 3,
#    'gust': 23,
#    'hi': 38,
#    'icon_code': 30,
#    'icon_extd': 3000,
#    'mslp': 29.71,
#    'num': 16,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 2,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 63,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 38,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0.08,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 29,
#    'wdir': 265,
#    'wdir_cardinal': 'W',
#    'wspd': 13,
#    'wxman': 'wx1110'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 31,
#    'day_ind': 'D',
#    'dewpt': 27,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523966400,
#    'fcst_valid_local': '2018-04-17T08:00:00-0400',
#    'feels_like': 32,
#    'golf_category': 'Poor',
#    'golf_index': 3,
#    'gust': 17,
#    'hi': 39,
#    'icon_code': 30,
#    'icon_extd': 3000,
#    'mslp': 29.71,
#    'num': 17,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 1,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 60,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 39,
#    'uv_desc': 'Low',
#    'uv_index': 1,
#    'uv_index_raw': 0.54,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 32,
#    'wdir': 268,
#    'wdir_cardinal': 'W',
#    'wspd': 11,
#    'wxman': 'wx1110'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 24,
#    'day_ind': 'D',
#    'dewpt': 26,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523970000,
#    'fcst_valid_local': '2018-04-17T09:00:00-0400',
#    'feels_like': 35,
#    'golf_category': 'Fair',
#    'golf_index': 4,
#    'gust': 18,
#    'hi': 42,
#    'icon_code': 34,
#    'icon_extd': 3400,
#    'mslp': 29.71,
#    'num': 18,
#    'phrase_12char': 'M Sunny',
#    'phrase_22char': 'Mostly Sunny',
#    'phrase_32char': 'Mostly Sunny',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 54,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Mostly',
#    'subphrase_pt2': 'Sunny',
#    'subphrase_pt3': '',
#    'temp': 42,
#    'uv_desc': 'Low',
#    'uv_index': 2,
#    'uv_index_raw': 1.66,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 35,
#    'wdir': 271,
#    'wdir_cardinal': 'W',
#    'wspd': 13,
#    'wxman': 'wx1010'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 49,
#    'day_ind': 'D',
#    'dewpt': 26,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523973600,
#    'fcst_valid_local': '2018-04-17T10:00:00-0400',
#    'feels_like': 36,
#    'golf_category': 'Fair',
#    'golf_index': 5,
#    'gust': 20,
#    'hi': 43,
#    'icon_code': 30,
#    'icon_extd': 3000,
#    'mslp': 29.7,
#    'num': 19,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 51,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 43,
#    'uv_desc': 'Moderate',
#    'uv_index': 3,
#    'uv_index_raw': 3.28,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 36,
#    'wdir': 272,
#    'wdir_cardinal': 'W',
#    'wspd': 15,
#    'wxman': 'wx1110'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 63,
#    'day_ind': 'D',
#    'dewpt': 26,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523977200,
#    'fcst_valid_local': '2018-04-17T11:00:00-0400',
#    'feels_like': 38,
#    'golf_category': 'Fair',
#    'golf_index': 5,
#    'gust': 22,
#    'hi': 45,
#    'icon_code': 28,
#    'icon_extd': 2800,
#    'mslp': 29.69,
#    'num': 20,
#    'phrase_12char': 'M Cloudy',
#    'phrase_22char': 'Mostly Cloudy',
#    'phrase_32char': 'Mostly Cloudy',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 47,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Mostly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 45,
#    'uv_desc': 'Moderate',
#    'uv_index': 4,
#    'uv_index_raw': 4.03,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 38,
#    'wdir': 276,
#    'wdir_cardinal': 'W',
#    'wspd': 16,
#    'wxman': 'wx1210'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 75,
#    'day_ind': 'D',
#    'dewpt': 26,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523980800,
#    'fcst_valid_local': '2018-04-17T12:00:00-0400',
#    'feels_like': 40,
#    'golf_category': 'Fair',
#    'golf_index': 5,
#    'gust': 22,
#    'hi': 47,
#    'icon_code': 28,
#    'icon_extd': 2800,
#    'mslp': 29.68,
#    'num': 21,
#    'phrase_12char': 'M Cloudy',
#    'phrase_22char': 'Mostly Cloudy',
#    'phrase_32char': 'Mostly Cloudy',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 44,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Mostly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 47,
#    'uv_desc': 'Moderate',
#    'uv_index': 4,
#    'uv_index_raw': 4.12,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 40,
#    'wdir': 275,
#    'wdir_cardinal': 'W',
#    'wspd': 16,
#    'wxman': 'wx1210'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 86,
#    'day_ind': 'D',
#    'dewpt': 26,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523984400,
#    'fcst_valid_local': '2018-04-17T13:00:00-0400',
#    'feels_like': 40,
#    'golf_category': 'Fair',
#    'golf_index': 5,
#    'gust': 23,
#    'hi': 46,
#    'icon_code': 26,
#    'icon_extd': 2600,
#    'mslp': 29.67,
#    'num': 22,
#    'phrase_12char': 'Cloudy',
#    'phrase_22char': 'Cloudy',
#    'phrase_32char': 'Cloudy',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 45,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Cloudy',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 46,
#    'uv_desc': 'Moderate',
#    'uv_index': 4,
#    'uv_index_raw': 4.48,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 40,
#    'wdir': 267,
#    'wdir_cardinal': 'W',
#    'wspd': 17,
#    'wxman': 'wx1210'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 86,
#    'day_ind': 'D',
#    'dewpt': 26,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523988000,
#    'fcst_valid_local': '2018-04-17T14:00:00-0400',
#    'feels_like': 40,
#    'golf_category': 'Fair',
#    'golf_index': 5,
#    'gust': 23,
#    'hi': 47,
#    'icon_code': 26,
#    'icon_extd': 2600,
#    'mslp': 29.66,
#    'num': 23,
#    'phrase_12char': 'Cloudy',
#    'phrase_22char': 'Cloudy',
#    'phrase_32char': 'Cloudy',
#    'pop': 7,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 45,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Cloudy',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 47,
#    'uv_desc': 'Moderate',
#    'uv_index': 4,
#    'uv_index_raw': 4.16,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 40,
#    'wdir': 265,
#    'wdir_cardinal': 'W',
#    'wspd': 17,
#    'wxman': 'wx1210'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 95,
#    'day_ind': 'D',
#    'dewpt': 26,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523991600,
#    'fcst_valid_local': '2018-04-17T15:00:00-0400',
#    'feels_like': 39,
#    'golf_category': 'Fair',
#    'golf_index': 5,
#    'gust': 25,
#    'hi': 47,
#    'icon_code': 26,
#    'icon_extd': 2600,
#    'mslp': 29.66,
#    'num': 24,
#    'phrase_12char': 'Cloudy',
#    'phrase_22char': 'Cloudy',
#    'phrase_32char': 'Cloudy',
#    'pop': 11,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 44,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Cloudy',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 47,
#    'uv_desc': 'Low',
#    'uv_index': 2,
#    'uv_index_raw': 2.26,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 39,
#    'wdir': 269,
#    'wdir_cardinal': 'W',
#    'wspd': 18,
#    'wxman': 'wx1210'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 94,
#    'day_ind': 'D',
#    'dewpt': 26,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523995200,
#    'fcst_valid_local': '2018-04-17T16:00:00-0400',
#    'feels_like': 40,
#    'golf_category': 'Fair',
#    'golf_index': 5,
#    'gust': 24,
#    'hi': 47,
#    'icon_code': 26,
#    'icon_extd': 2600,
#    'mslp': 29.66,
#    'num': 25,
#    'phrase_12char': 'Cloudy',
#    'phrase_22char': 'Cloudy',
#    'phrase_32char': 'Cloudy',
#    'pop': 18,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 44,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Cloudy',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 47,
#    'uv_desc': 'Low',
#    'uv_index': 1,
#    'uv_index_raw': 1.49,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 40,
#    'wdir': 271,
#    'wdir_cardinal': 'W',
#    'wspd': 18,
#    'wxman': 'wx1210'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 95,
#    'day_ind': 'D',
#    'dewpt': 25,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1523998800,
#    'fcst_valid_local': '2018-04-17T17:00:00-0400',
#    'feels_like': 39,
#    'golf_category': 'Fair',
#    'golf_index': 5,
#    'gust': 24,
#    'hi': 46,
#    'icon_code': 26,
#    'icon_extd': 2600,
#    'mslp': 29.67,
#    'num': 26,
#    'phrase_12char': 'Cloudy',
#    'phrase_22char': 'Cloudy',
#    'phrase_32char': 'Cloudy',
#    'pop': 11,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 44,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Cloudy',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 46,
#    'uv_desc': 'Low',
#    'uv_index': 1,
#    'uv_index_raw': 0.77,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 39,
#    'wdir': 274,
#    'wdir_cardinal': 'W',
#    'wspd': 18,
#    'wxman': 'wx1210'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 88,
#    'day_ind': 'D',
#    'dewpt': 25,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524002400,
#    'fcst_valid_local': '2018-04-17T18:00:00-0400',
#    'feels_like': 38,
#    'golf_category': 'Fair',
#    'golf_index': 5,
#    'gust': 24,
#    'hi': 45,
#    'icon_code': 26,
#    'icon_extd': 2600,
#    'mslp': 29.68,
#    'num': 27,
#    'phrase_12char': 'Cloudy',
#    'phrase_22char': 'Cloudy',
#    'phrase_32char': 'Cloudy',
#    'pop': 8,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 44,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Cloudy',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 45,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0.26,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 38,
#    'wdir': 277,
#    'wdir_cardinal': 'W',
#    'wspd': 17,
#    'wxman': 'wx1210'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 68,
#    'day_ind': 'D',
#    'dewpt': 24,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524006000,
#    'fcst_valid_local': '2018-04-17T19:00:00-0400',
#    'feels_like': 38,
#    'golf_category': 'Fair',
#    'golf_index': 5,
#    'gust': 21,
#    'hi': 44,
#    'icon_code': 28,
#    'icon_extd': 2800,
#    'mslp': 29.7,
#    'num': 28,
#    'phrase_12char': 'M Cloudy',
#    'phrase_22char': 'Mostly Cloudy',
#    'phrase_32char': 'Mostly Cloudy',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 45,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Mostly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 44,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0.07,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 38,
#    'wdir': 279,
#    'wdir_cardinal': 'W',
#    'wspd': 14,
#    'wxman': 'wx1210'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 52,
#    'day_ind': 'N',
#    'dewpt': 24,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524009600,
#    'fcst_valid_local': '2018-04-17T20:00:00-0400',
#    'feels_like': 37,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 18,
#    'hi': 43,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.72,
#    'num': 29,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 47,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 43,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 37,
#    'wdir': 274,
#    'wdir_cardinal': 'W',
#    'wspd': 12,
#    'wxman': 'wx1610'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 33,
#    'day_ind': 'N',
#    'dewpt': 25,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524013200,
#    'fcst_valid_local': '2018-04-17T21:00:00-0400',
#    'feels_like': 36,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 19,
#    'hi': 42,
#    'icon_code': 29,
#    'icon_extd': 2900,
#    'mslp': 29.75,
#    'num': 30,
#    'phrase_12char': 'P Cloudy',
#    'phrase_22char': 'Partly Cloudy',
#    'phrase_32char': 'Partly Cloudy',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 50,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Partly',
#    'subphrase_pt2': 'Cloudy',
#    'subphrase_pt3': '',
#    'temp': 42,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 36,
#    'wdir': 272,
#    'wdir_cardinal': 'W',
#    'wspd': 12,
#    'wxman': 'wx1610'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 17,
#    'day_ind': 'N',
#    'dewpt': 25,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524016800,
#    'fcst_valid_local': '2018-04-17T22:00:00-0400',
#    'feels_like': 35,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 19,
#    'hi': 41,
#    'icon_code': 31,
#    'icon_extd': 3100,
#    'mslp': 29.77,
#    'num': 31,
#    'phrase_12char': 'Clear',
#    'phrase_22char': 'Clear',
#    'phrase_32char': 'Clear',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 52,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Clear',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 41,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 35,
#    'wdir': 269,
#    'wdir_cardinal': 'W',
#    'wspd': 11,
#    'wxman': 'wx1510'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 15,
#    'day_ind': 'N',
#    'dewpt': 25,
#    'dow': 'Tuesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524020400,
#    'fcst_valid_local': '2018-04-17T23:00:00-0400',
#    'feels_like': 33,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 18,
#    'hi': 40,
#    'icon_code': 31,
#    'icon_extd': 3100,
#    'mslp': 29.78,
#    'num': 32,
#    'phrase_12char': 'Clear',
#    'phrase_22char': 'Clear',
#    'phrase_32char': 'Clear',
#    'pop': 0,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 55,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Clear',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 40,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 33,
#    'wdir': 270,
#    'wdir_cardinal': 'W',
#    'wspd': 10,
#    'wxman': 'wx1510'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 9,
#    'day_ind': 'N',
#    'dewpt': 25,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524024000,
#    'fcst_valid_local': '2018-04-18T00:00:00-0400',
#    'feels_like': 32,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 18,
#    'hi': 39,
#    'icon_code': 31,
#    'icon_extd': 3100,
#    'mslp': 29.78,
#    'num': 33,
#    'phrase_12char': 'Clear',
#    'phrase_22char': 'Clear',
#    'phrase_32char': 'Clear',
#    'pop': 1,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 57,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Clear',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 39,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 32,
#    'wdir': 273,
#    'wdir_cardinal': 'W',
#    'wspd': 11,
#    'wxman': 'wx1510'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 7,
#    'day_ind': 'N',
#    'dewpt': 25,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524027600,
#    'fcst_valid_local': '2018-04-18T01:00:00-0400',
#    'feels_like': 31,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 18,
#    'hi': 38,
#    'icon_code': 31,
#    'icon_extd': 3100,
#    'mslp': 29.79,
#    'num': 34,
#    'phrase_12char': 'Clear',
#    'phrase_22char': 'Clear',
#    'phrase_32char': 'Clear',
#    'pop': 1,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 59,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Clear',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 38,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 31,
#    'wdir': 274,
#    'wdir_cardinal': 'W',
#    'wspd': 10,
#    'wxman': 'wx1510'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 4,
#    'day_ind': 'N',
#    'dewpt': 24,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524031200,
#    'fcst_valid_local': '2018-04-18T02:00:00-0400',
#    'feels_like': 30,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 19,
#    'hi': 38,
#    'icon_code': 31,
#    'icon_extd': 3100,
#    'mslp': 29.8,
#    'num': 35,
#    'phrase_12char': 'Clear',
#    'phrase_22char': 'Clear',
#    'phrase_32char': 'Clear',
#    'pop': 1,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 58,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Clear',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 38,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 30,
#    'wdir': 281,
#    'wdir_cardinal': 'W',
#    'wspd': 11,
#    'wxman': 'wx1510'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 1,
#    'day_ind': 'N',
#    'dewpt': 25,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524034800,
#    'fcst_valid_local': '2018-04-18T03:00:00-0400',
#    'feels_like': 30,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': 17,
#    'hi': 37,
#    'icon_code': 31,
#    'icon_extd': 3100,
#    'mslp': 29.8,
#    'num': 36,
#    'phrase_12char': 'Clear',
#    'phrase_22char': 'Clear',
#    'phrase_32char': 'Clear',
#    'pop': 2,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 61,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Clear',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 37,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 30,
#    'wdir': 283,
#    'wdir_cardinal': 'WNW',
#    'wspd': 9,
#    'wxman': 'wx1510'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 6,
#    'day_ind': 'N',
#    'dewpt': 25,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524038400,
#    'fcst_valid_local': '2018-04-18T04:00:00-0400',
#    'feels_like': 29,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': None,
#    'hi': 36,
#    'icon_code': 31,
#    'icon_extd': 3100,
#    'mslp': 29.8,
#    'num': 37,
#    'phrase_12char': 'Clear',
#    'phrase_22char': 'Clear',
#    'phrase_32char': 'Clear',
#    'pop': 2,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 64,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Clear',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 36,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 29,
#    'wdir': 283,
#    'wdir_cardinal': 'WNW',
#    'wspd': 8,
#    'wxman': 'wx1510'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 5,
#    'day_ind': 'N',
#    'dewpt': 26,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524042000,
#    'fcst_valid_local': '2018-04-18T05:00:00-0400',
#    'feels_like': 29,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': None,
#    'hi': 36,
#    'icon_code': 31,
#    'icon_extd': 3100,
#    'mslp': 29.81,
#    'num': 38,
#    'phrase_12char': 'Clear',
#    'phrase_22char': 'Clear',
#    'phrase_32char': 'Clear',
#    'pop': 3,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 67,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Clear',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 36,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 29,
#    'wdir': 277,
#    'wdir_cardinal': 'W',
#    'wspd': 8,
#    'wxman': 'wx1510'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 2,
#    'day_ind': 'N',
#    'dewpt': 26,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524045600,
#    'fcst_valid_local': '2018-04-18T06:00:00-0400',
#    'feels_like': 29,
#    'golf_category': '',
#    'golf_index': None,
#    'gust': None,
#    'hi': 35,
#    'icon_code': 31,
#    'icon_extd': 3100,
#    'mslp': 29.83,
#    'num': 39,
#    'phrase_12char': 'Clear',
#    'phrase_22char': 'Clear',
#    'phrase_32char': 'Clear',
#    'pop': 3,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 68,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Clear',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 35,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 29,
#    'wdir': 269,
#    'wdir_cardinal': 'W',
#    'wspd': 9,
#    'wxman': 'wx1510'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 3,
#    'day_ind': 'D',
#    'dewpt': 26,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524049200,
#    'fcst_valid_local': '2018-04-18T07:00:00-0400',
#    'feels_like': 29,
#    'golf_category': 'Poor',
#    'golf_index': 3,
#    'gust': 18,
#    'hi': 36,
#    'icon_code': 32,
#    'icon_extd': 3200,
#    'mslp': 29.84,
#    'num': 40,
#    'phrase_12char': 'Sunny',
#    'phrase_22char': 'Sunny',
#    'phrase_32char': 'Sunny',
#    'pop': 2,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 65,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Sunny',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 36,
#    'uv_desc': 'Low',
#    'uv_index': 0,
#    'uv_index_raw': 0.09,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 29,
#    'wdir': 267,
#    'wdir_cardinal': 'W',
#    'wspd': 10,
#    'wxman': 'wx1010'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 3,
#    'day_ind': 'D',
#    'dewpt': 26,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524052800,
#    'fcst_valid_local': '2018-04-18T08:00:00-0400',
#    'feels_like': 32,
#    'golf_category': 'Poor',
#    'golf_index': 3,
#    'gust': 17,
#    'hi': 39,
#    'icon_code': 32,
#    'icon_extd': 3200,
#    'mslp': 29.86,
#    'num': 41,
#    'phrase_12char': 'Sunny',
#    'phrase_22char': 'Sunny',
#    'phrase_32char': 'Sunny',
#    'pop': 1,
#    'precip_type': 'precip',
#    'qpf': 0.0,
#    'rh': 61,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Sunny',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 39,
#    'uv_desc': 'Low',
#    'uv_index': 1,
#    'uv_index_raw': 0.56,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 32,
#    'wdir': 267,
#    'wdir_cardinal': 'W',
#    'wspd': 11,
#    'wxman': 'wx1010'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 1,
#    'day_ind': 'D',
#    'dewpt': 27,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524056400,
#    'fcst_valid_local': '2018-04-18T09:00:00-0400',
#    'feels_like': 36,
#    'golf_category': 'Fair',
#    'golf_index': 4,
#    'gust': 19,
#    'hi': 43,
#    'icon_code': 32,
#    'icon_extd': 3200,
#    'mslp': 29.86,
#    'num': 42,
#    'phrase_12char': 'Sunny',
#    'phrase_22char': 'Sunny',
#    'phrase_32char': 'Sunny',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 53,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Sunny',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 43,
#    'uv_desc': 'Low',
#    'uv_index': 2,
#    'uv_index_raw': 1.69,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 36,
#    'wdir': 273,
#    'wdir_cardinal': 'W',
#    'wspd': 13,
#    'wxman': 'wx1010'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 1,
#    'day_ind': 'D',
#    'dewpt': 28,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524060000,
#    'fcst_valid_local': '2018-04-18T10:00:00-0400',
#    'feels_like': 40,
#    'golf_category': 'Fair',
#    'golf_index': 5,
#    'gust': 19,
#    'hi': 46,
#    'icon_code': 32,
#    'icon_extd': 3200,
#    'mslp': 29.85,
#    'num': 43,
#    'phrase_12char': 'Sunny',
#    'phrase_22char': 'Sunny',
#    'phrase_32char': 'Sunny',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 49,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Sunny',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 46,
#    'uv_desc': 'Moderate',
#    'uv_index': 3,
#    'uv_index_raw': 3.32,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 40,
#    'wdir': 275,
#    'wdir_cardinal': 'W',
#    'wspd': 14,
#    'wxman': 'wx1010'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 1,
#    'day_ind': 'D',
#    'dewpt': 28,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524063600,
#    'fcst_valid_local': '2018-04-18T11:00:00-0400',
#    'feels_like': 43,
#    'golf_category': 'Good',
#    'golf_index': 6,
#    'gust': 19,
#    'hi': 49,
#    'icon_code': 32,
#    'icon_extd': 3200,
#    'mslp': 29.84,
#    'num': 44,
#    'phrase_12char': 'Sunny',
#    'phrase_22char': 'Sunny',
#    'phrase_32char': 'Sunny',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 45,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Sunny',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 49,
#    'uv_desc': 'Moderate',
#    'uv_index': 5,
#    'uv_index_raw': 5.09,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 43,
#    'wdir': 276,
#    'wdir_cardinal': 'W',
#    'wspd': 14,
#    'wxman': 'wx1050'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 1,
#    'day_ind': 'D',
#    'dewpt': 29,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524067200,
#    'fcst_valid_local': '2018-04-18T12:00:00-0400',
#    'feels_like': 45,
#    'golf_category': 'Good',
#    'golf_index': 6,
#    'gust': 20,
#    'hi': 50,
#    'icon_code': 32,
#    'icon_extd': 3200,
#    'mslp': 29.83,
#    'num': 45,
#    'phrase_12char': 'Sunny',
#    'phrase_22char': 'Sunny',
#    'phrase_32char': 'Sunny',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 43,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Sunny',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 50,
#    'uv_desc': 'High',
#    'uv_index': 7,
#    'uv_index_raw': 6.5,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 45,
#    'wdir': 269,
#    'wdir_cardinal': 'W',
#    'wspd': 15,
#    'wxman': 'wx1050'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 2,
#    'day_ind': 'D',
#    'dewpt': 30,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524070800,
#    'fcst_valid_local': '2018-04-18T13:00:00-0400',
#    'feels_like': 48,
#    'golf_category': 'Good',
#    'golf_index': 7,
#    'gust': 19,
#    'hi': 52,
#    'icon_code': 32,
#    'icon_extd': 3200,
#    'mslp': 29.82,
#    'num': 46,
#    'phrase_12char': 'Sunny',
#    'phrase_22char': 'Sunny',
#    'phrase_32char': 'Sunny',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 42,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Sunny',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 52,
#    'uv_desc': 'High',
#    'uv_index': 7,
#    'uv_index_raw': 7.07,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 48,
#    'wdir': 265,
#    'wdir_cardinal': 'W',
#    'wspd': 14,
#    'wxman': 'wx1050'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 2,
#    'day_ind': 'D',
#    'dewpt': 31,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524074400,
#    'fcst_valid_local': '2018-04-18T14:00:00-0400',
#    'feels_like': 50,
#    'golf_category': 'Good',
#    'golf_index': 7,
#    'gust': 19,
#    'hi': 54,
#    'icon_code': 32,
#    'icon_extd': 3200,
#    'mslp': 29.81,
#    'num': 47,
#    'phrase_12char': 'Sunny',
#    'phrase_22char': 'Sunny',
#    'phrase_32char': 'Sunny',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 41,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Sunny',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 54,
#    'uv_desc': 'High',
#    'uv_index': 7,
#    'uv_index_raw': 6.56,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 50,
#    'wdir': 265,
#    'wdir_cardinal': 'W',
#    'wspd': 14,
#    'wxman': 'wx1050'},
#   {'class': 'fod_long_range_hourly',
#    'clds': 2,
#    'day_ind': 'D',
#    'dewpt': 31,
#    'dow': 'Wednesday',
#    'expire_time_gmt': 1523910265,
#    'fcst_valid': 1524078000,
#    'fcst_valid_local': '2018-04-18T15:00:00-0400',
#    'feels_like': 52,
#    'golf_category': 'Good',
#    'golf_index': 7,
#    'gust': 19,
#    'hi': 55,
#    'icon_code': 32,
#    'icon_extd': 3200,
#    'mslp': 29.79,
#    'num': 48,
#    'phrase_12char': 'Sunny',
#    'phrase_22char': 'Sunny',
#    'phrase_32char': 'Sunny',
#    'pop': 0,
#    'precip_type': 'rain',
#    'qpf': 0.0,
#    'rh': 40,
#    'severity': 1,
#    'snow_qpf': 0.0,
#    'subphrase_pt1': 'Sunny',
#    'subphrase_pt2': '',
#    'subphrase_pt3': '',
#    'temp': 55,
#    'uv_desc': 'Moderate',
#    'uv_index': 5,
#    'uv_index_raw': 5.18,
#    'uv_warning': 0,
#    'vis': 10.0,
#    'wc': 52,
#    'wdir': 261,
#    'wdir_cardinal': 'W',
#    'wspd': 14,
#    'wxman': 'wx1050'}],
#  'metadata': {'expire_time_gmt': 1523909235,
#   'language': 'en-US',
#   'latitude': 39.74,
#   'longitude': -75.54,
#   'status_code': 200,
#   'transaction_id': '1523908970715:1869708002',
#   'units': 'e',
#   'version': '1'}}

# %% [markdown]
# This call gives the current weather condition of Wilmington, DE.

# %%
page = requests.get('https://443c601f-53bd-460e-aeab-21f85f5df7bc:xs48O8pSRA@twcservice.mybluemix.net/api/weather/v1/geocode/39.74/-75.54/observations.json')
page.json()
# Out:
# {'metadata': {'expire_time_gmt': 1523915460,
#   'language': 'en-US',
#   'latitude': 39.74,
#   'longitude': -75.54,
#   'status_code': 200,
#   'transaction_id': '1523909606248:172976982',
#   'version': '1'},
#  'observation': {'blunt_phrase': None,
#   'class': 'observation',
#   'clds': 'OVC',
#   'day_ind': 'D',
#   'dewPt': 45,
#   'expire_time_gmt': 1523915460,
#   'feels_like': 50,
#   'gust': 24,
#   'heat_index': 50,
#   'icon_extd': 1201,
#   'key': 'KILG',
#   'max_temp': None,
#   'min_temp': None,
#   'obs_id': 'KILG',
#   'obs_name': 'Wilmington',
#   'precip_hrly': 0.0,
#   'precip_total': None,
#   'pressure': 29.45,
#   'pressure_desc': None,
#   'pressure_tend': None,
#   'primary_swell_direction': None,
#   'primary_swell_height': None,
#   'primary_swell_period': None,
#   'primary_wave_height': None,
#   'primary_wave_period': None,
#   'qualifier': None,
#   'qualifier_svrty': None,
#   'rh': 83,
#   'secondary_swell_direction': None,
#   'secondary_swell_height': None,
#   'secondary_swell_period': None,
#   'snow_hrly': None,
#   'temp': 50,
#   'terse_phrase': None,
#   'uv_desc': 'Low',
#   'uv_index': 1,
#   'valid_time_gmt': 1523908260,
#   'vis': 10,
#   'water_temp': None,
#   'wc': 50,
#   'wdir': 280,
#   'wdir_cardinal': 'W',
#   'wspd': 16,
#   'wx_icon': 11,
#   'wx_phrase': 'Light Rain'}}

# %% [markdown]
# ### AccuWeather API

# %% [markdown]
# AccuWeather both has free and paid plans as shown below. However, its free plan is very limited and very hard to use.

# %% [markdown]
# <img src="./imgs/AccuWeatherAPI.jpg" width='90%'>

# %% [markdown]
# The tricky part about AccuWeather API is that you cannot retrieve a location's weather information using the location's geo coordinates. AccuWeather API is only able to return a location Key according to the geo coordinates that you offer. However, you can use the location key to invoke another API call to retrieve weather information.

# %% [markdown]
# Below is a brief demo to show how we can find the location key for Western Susses, DE and further get the location's weather information.
# First, get the location key.
# A brief explanation of this api call:
# 1, http://dataservice.accuweather.com : api address
# 2, locations/v1/cities/geoposition : to retrieve a location information using geo coordinates, you can replace it with other requests such as 'forecasts/v1/daily/1day/', which retrieves one-day weather forecast. More options can be found at https://developer.accuweather.com/apis
# 3, apikey=VUMs2LH3pRqoU71wT4xNAAlaQA9wIAFF : your api key
# 4, q=38.76%2C-75.60 : geo coordinates of the location of interest
# 5, language=en-us : language option
# 6, details=true : show all details

# %%
page = requests.get("http://dataservice.accuweather.com/locations/v1/cities/geoposition/search?apikey=VUMs2LH3pRqoU71wT4xNAAlaQA9wIAFF&q=38.76%2C-75.60&language=en-us&details=true")

# %%
page.json()
# Out:
# {'AdministrativeArea': {'CountryID': 'US',
#   'EnglishName': 'Delaware',
#   'EnglishType': 'State',
#   'ID': 'DE',
#   'Level': 1,
#   'LocalizedName': 'Delaware',
#   'LocalizedType': 'State'},
#  'Country': {'EnglishName': 'United States',
#   'ID': 'US',
#   'LocalizedName': 'United States'},
#  'DataSets': ['Alerts',
#   'DailyAirQualityForecast',
#   'DailyPollenForecast',
#   'ForecastConfidence',
#   'MinuteCast'],
#  'Details': {'BandMap': 'USVA',
#   'CanonicalLocationKey': '2218423',
#   'CanonicalPostalCode': '19933',
#   'Climo': 'GEDD',
#   'DMA': {'EnglishName': 'Salisbury, MD', 'ID': '576'},
#   'Key': '2218423',
#   'LocalRadar': 'KDOV',
#   'MarineStation': '',
#   'MarineStationGMTOffset': None,
#   'MediaRegion': 'NE',
#   'Metar': 'KGED',
#   'NXMetro': '',
#   'NXState': 'VA_',
#   'PartnerID': None,
#   'Population': 2337,
#   'PrimaryWarningCountyCode': 'DEC005',
#   'PrimaryWarningZoneCode': 'DEZ003',
#   'Satellite': 'VA_',
#   'Sources': [{'DataType': 'CurrentConditions',
#     'Source': 'AccuWeather',
#     'SourceId': 1},
#    {'DataType': 'DailyAirQualityForecast',
#     'Source': 'AccuWeather',
#     'SourceId': 1},
#    {'DataType': 'DailyForecast', 'Source': 'AccuWeather', 'SourceId': 1},
#    {'DataType': 'DailyPollenForecast', 'Source': 'AccuWeather', 'SourceId': 1},
#    {'DataType': 'ForecastConfidence', 'Source': 'AccuWeather', 'SourceId': 1},
#    {'DataType': 'HourlyForecast', 'Source': 'AccuWeather', 'SourceId': 1},
#    {'DataType': 'MinuteCast', 'Source': 'AccuWeather', 'SourceId': 1},
#    {'DataType': 'Alerts',
#     'Source': 'U.S. National Weather Service',
#     'SourceId': 2}],
#   'StationCode': 'DEBR',
#   'StationGmtOffset': -5.0,
#   'Synoptic': '72402',
#   'VideoCode': 'BWI'},
#  'EnglishName': 'Bridgeville',
#  'GeoPosition': {'Elevation': {'Imperial': {'Unit': 'ft',
#     'UnitType': 0,
#     'Value': 42.0},
#    'Metric': {'Unit': 'm', 'UnitType': 5, 'Value': 13.0}},
#   'Latitude': 38.743,
#   'Longitude': -75.604},
#  'IsAlias': False,
#  'Key': '2218423',
#  'LocalizedName': 'Bridgeville',
#  'PrimaryPostalCode': '19933',
#  'Rank': 85,
#  'Region': {'EnglishName': 'North America',
#   'ID': 'NAM',
#   'LocalizedName': 'North America'},
#  'SupplementalAdminAreas': [{'EnglishName': 'Sussex',
#    'Level': 2,
#    'LocalizedName': 'Sussex'}],
#  'TimeZone': {'Code': 'EDT',
#   'GmtOffset': -4.0,
#   'IsDaylightSaving': True,
#   'Name': 'America/New_York',
#   'NextOffsetChange': '2018-11-04T06:00:00Z'},
#  'Type': 'City',
#  'Version': 1}

# %% [markdown]
# We find the location key is 2219423 for Western Sussex, DE. Then we invoke a second API call to retrieve the location's one-day weather forecast.
# In the following api code:
# 1, http://dataservice.accuweather.com : api address
# 2, forecasts/v1/daily/1day/ : to retrieve one-day weather forecast. More options can be found at https://developer.accuweather.com/apis
# 3, 2218423 : location key
# 4, apikey=VUMs2LH3pRqoU71wT4xNAAlaQA9wIAFF : your api key
# 5, language=en-us : language option
# 6, details=true : show all details

# %%
secondCall = requests.get("http://dataservice.accuweather.com/forecasts/v1/daily/1day/2218423?apikey=VUMs2LH3pRqoU71wT4xNAAlaQA9wIAFF&language=en-us&details=true")
secondCall.json()
# Out:
# {'DailyForecasts': [{'AirAndPollen': [{'Category': 'Good',
#      'CategoryValue': 1,
#      'Name': 'AirQuality',
#      'Type': 'Ozone',
#      'Value': 43},
#     {'Category': 'Low', 'CategoryValue': 1, 'Name': 'Grass', 'Value': 2},
#     {'Category': 'Low', 'CategoryValue': 1, 'Name': 'Mold', 'Value': 400},
#     {'Category': 'Low', 'CategoryValue': 1, 'Name': 'Ragweed', 'Value': 0},
#     {'Category': 'High', 'CategoryValue': 3, 'Name': 'Tree', 'Value': 350},
#     {'Category': 'Low', 'CategoryValue': 1, 'Name': 'UVIndex', 'Value': 2}],
#    'Date': '2018-04-16T07:00:00-04:00',
#    'Day': {'CloudCover': 97,
#     'HoursOfIce': 0.0,
#     'HoursOfPrecipitation': 2.5,
#     'HoursOfRain': 2.5,
#     'HoursOfSnow': 0.0,
#     'Ice': {'Unit': 'in', 'UnitType': 1, 'Value': 0.0},
#     'IceProbability': 0,
#     'Icon': 18,
#     'IconPhrase': 'Rain',
#     'LongPhrase': 'Breezy; heavy rain and a t-storm late this morning followed by a brief shower or two this afternoon',
#     'PrecipitationProbability': 65,
#     'Rain': {'Unit': 'in', 'UnitType': 1, 'Value': 0.09},
#     'RainProbability': 64,
#     'ShortPhrase': 'Heavy rain and a thunderstorm',
#     'Snow': {'Unit': 'in', 'UnitType': 1, 'Value': 0.0},
#     'SnowProbability': 0,
#     'ThunderstormProbability': 30,
#     'TotalLiquid': {'Unit': 'in', 'UnitType': 1, 'Value': 0.09},
#     'Wind': {'Direction': {'Degrees': 227, 'English': 'SW', 'Localized': 'SW'},
#      'Speed': {'Unit': 'mi/h', 'UnitType': 9, 'Value': 15.0}},
#     'WindGust': {'Direction': {'Degrees': 177,
#       'English': 'S',
#       'Localized': 'S'},
#      'Speed': {'Unit': 'mi/h', 'UnitType': 9, 'Value': 31.1}}},
#    'DegreeDaySummary': {'Cooling': {'Unit': 'F', 'UnitType': 18, 'Value': 0.0},
#     'Heating': {'Unit': 'F', 'UnitType': 18, 'Value': 15.0}},
#    'EpochDate': 1523876400,
#    'HoursOfSun': 2.0,
#    'Link': 'http://www.accuweather.com/en/us/bridgeville-de/19933/daily-weather-forecast/2218423?day=1&lang=en-us',
#    'MobileLink': 'http://m.accuweather.com/en/us/bridgeville-de/19933/daily-weather-forecast/2218423?day=1&lang=en-us',
#    'Moon': {'Age': 0,
#     'EpochRise': 1523876700,
#     'EpochSet': 1523924760,
#     'Phase': 'New',
#     'Rise': '2018-04-16T07:05:00-04:00',
#     'Set': '2018-04-16T20:26:00-04:00'},
#    'Night': {'CloudCover': 67,
#     'HoursOfIce': 0.0,
#     'HoursOfPrecipitation': 0.0,
#     'HoursOfRain': 0.0,
#     'HoursOfSnow': 0.0,
#     'Ice': {'Unit': 'in', 'UnitType': 1, 'Value': 0.0},
#     'IceProbability': 0,
#     'Icon': 36,
#     'IconPhrase': 'Intermittent clouds',
#     'LongPhrase': 'Partly cloudy',
#     'PrecipitationProbability': 25,
#     'Rain': {'Unit': 'in', 'UnitType': 1, 'Value': 0.0},
#     'RainProbability': 25,
#     'ShortPhrase': 'Partly cloudy',
#     'Snow': {'Unit': 'in', 'UnitType': 1, 'Value': 0.0},
#     'SnowProbability': 0,
#     'ThunderstormProbability': 7,
#     'TotalLiquid': {'Unit': 'in', 'UnitType': 1, 'Value': 0.0},
#     'Wind': {'Direction': {'Degrees': 260, 'English': 'W', 'Localized': 'W'},
#      'Speed': {'Unit': 'mi/h', 'UnitType': 9, 'Value': 6.9}},
#     'WindGust': {'Direction': {'Degrees': 263,
#       'English': 'W',
#       'Localized': 'W'},
#      'Speed': {'Unit': 'mi/h', 'UnitType': 9, 'Value': 15.0}}},
#    'RealFeelTemperature': {'Maximum': {'Unit': 'F',
#      'UnitType': 18,
#      'Value': 58.0},
#     'Minimum': {'Unit': 'F', 'UnitType': 18, 'Value': 35.0}},
#    'RealFeelTemperatureShade': {'Maximum': {'Unit': 'F',
#      'UnitType': 18,
#      'Value': 58.0},
#     'Minimum': {'Unit': 'F', 'UnitType': 18, 'Value': 35.0}},
#    'Sources': ['AccuWeather'],
#    'Sun': {'EpochRise': 1523874300,
#     'EpochSet': 1523922000,
#     'Rise': '2018-04-16T06:25:00-04:00',
#     'Set': '2018-04-16T19:40:00-04:00'},
#    'Temperature': {'Maximum': {'Unit': 'F', 'UnitType': 18, 'Value': 61.0},
#     'Minimum': {'Unit': 'F', 'UnitType': 18, 'Value': 39.0}}}],
#  'Headline': {'Category': 'thunderstorm',
#   'EffectiveDate': '2018-04-16T11:00:00-04:00',
#   'EffectiveEpochDate': 1523890800,
#   'EndDate': '2018-04-16T20:00:00-04:00',
#   'EndEpochDate': 1523923200,
#   'Link': 'http://www.accuweather.com/en/us/bridgeville-de/19933/daily-weather-forecast/2218423?lang=en-us',
#   'MobileLink': 'http://m.accuweather.com/en/us/bridgeville-de/19933/extended-weather-forecast/2218423?lang=en-us',
#   'Severity': 5,
#   'Text': 'Rain and thunderstorms late this morning through this afternoon'}}
